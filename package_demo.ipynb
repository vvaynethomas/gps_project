# %%
from gps_package import *

# %%
import pickle
import random

# %%
# full_data.info()

# %%
full_data,G = load_location()
# Out:
# attempting to load pickle from Shanghai_China_graph.p
# loaded graph for Shanghai, China
# loading data

# %%
full_data.head()
# Out:
#    uid  date_in_days  week  start_time_in_seconds  end_time_in_seconds  \
# 0  146         15996     5             1382053013           1382053037
# 1  146         15996     5             1382053282           1382056978
# 2  146         15996     5             1382066805           1382066995
# 3  146         16216     1             1401056822           1401056998
# 4  146         16216     1             1401057000           1401059946
#
#    start_longitude  start_latitude  end_longitude  end_latitude  activitytrip  \
# 0       121.483090       31.281703     121.483142     31.281787             0
# 1       121.483192       31.281846     121.420448     31.207532             1
# 2       121.420343       31.207485     121.421642     31.206600             0
# 3       121.431495       31.202385     121.431598     31.200608             0
# 4       121.431599       31.200593     121.431700     31.024567             1
#
#    trip_mode  start_location  end_location  activity_type
# ...

# %%
test_user_id = random.choice(full_data.uid)
test_user = extract_user(full_data,test_user_id)

# %%
outliers = generate_data(object='trip',n=5)

# %%
full_comm = Community(data=full_data,G=G)
# Out:
# added user #0; id 146
# added user #1; id 152
# added user #2; id 195
# added user #3; id 313
# added user #4; id 314
# added user #5; id 315
# added user #6; id 322
# added user #7; id 323
# added user #8; id 324
# added user #9; id 335
# added user #10; id 341
# added user #11; id 344
# added user #12; id 345
# added user #13; id 376
# added user #14; id 380
# added user #15; id 404
# added user #16; id 405
# added user #17; id 409
# added user #18; id 410
# added user #19; id 411
# added user #20; id 412
# added user #21; id 413
# added user #22; id 417
# added user #23; id 421
# added user #24; id 422
# added user #25; id 429
# added user #26; id 432
# added user #27; id 433
# added user #28; id 434
# added user #29; id 436
# added user #30; id 437
# added user #31; id 439
# added user #32; id 448
# added user #33; id 450
# added user #34; id 452
# added user #35; id 453
# added user #36; id 454
# added user #37; id 456
# added user #38; id 457
# added user #39; id 458
# ...

# %%
ad = pickle.load(open("full_comm_ad.p", 'rb'))

# %%
ad.fit(model_type='ocs')

# %%
train_preds = ad.predict()

# %%
df = ad.train

# %%
df['prediction'] = train_preds

# %%
from sklearn.metrics.cluster import adjusted_rand_score
print(df.describe())
# adjusted_rand_score(df.uid.tolist(),train_preds)
# Out:
#                 uid     timestamp      latitude     longitude  nearest_node  \
# count  20816.000000  2.081600e+04  20816.000000  20816.000000  2.081600e+04
# mean    2842.034493  1.425241e+09     31.191935    121.422008  2.104035e+09
# std     2293.908642  1.704004e+07      0.141907      0.133478  2.127071e+09
# min      146.000000  1.382053e+09     30.000058    120.000050  6.110468e+07
# 25%      646.000000  1.402621e+09     31.153316    121.377579  6.004965e+08
# 50%      802.000000  1.435151e+09     31.209416    121.433477  1.091233e+09
# 75%     5202.000000  1.438097e+09     31.265770    121.484257  3.109467e+09
# max     5281.000000  1.449235e+09     31.999998    122.062761  8.712525e+09
#
#                 vid    prediction
# count  20816.000000  20816.000000
# mean      54.955803     -0.245292
# std       45.411382      0.969473
# min        1.000000     -1.000000
# 25%       21.000000     -1.000000
# 50%       44.000000     -1.000000
# 75%       77.000000      1.000000
# ...

# %%
df.latitude.min()
# Out:
# 30.0000583333333

# %%
print([i for i in range(1)])
# Out:
# [0]

# %%
temp_visit = df.sample()
new_lat = temp_visit.latitude.values
new_lat
# Out:
# array([31.11649135])

# %%
anom_index = where(pred==-1)
values = x[anom_index]
plt.scatter(x[:,0], x[:,1])
plt.scatter(values[:,0], values[:,1], color='r')
plt.show()

# %%
# ad = gps_anomaly_detector(full_comm, kind='trip')

# %%
# pickle.dump( ad, open( "full_comm_ad.p", "wb" ) )

# %%
# g_comm = pickle.load( open( "full_comm_ad.p", "rb" ) )
